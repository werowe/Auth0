# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/Auth0/blob/main/numpy/sept-22-2023-numpy-calculate-lse_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np


study=np.array([9, 2, 6, 4,8])

results=np.array([100, 50, 80, 75, 85])


# weights
coefficient=6

# y-intercept
yintercept=43

prediction=coefficient*study+yintercept
prediction
# Out:
# array([97, 55, 79, 67, 91])

# %%
study=np.array([9, 2, 6, 4,8])

results=np.array([100, 50, 80, 75, 85])
prediction=np.array([97.3,55.1,79.2,67.1,91.3])

df=pd.DataFrame({
    "study": study,
    "results": results
    "prediction": prediction
}
)


def fsilly(d):
  return d * 2



df['silly']=df.apply(fsilly)

df

# %%
df
# Out:
#    study  results
# 0      9      100
# 1      2       50
# 2      6       80
# 3      4       75
# 4      8       85

# %%
# pandas when it has more than 1 column is called a dataframe
# when it has only one column it's called a series

df['study']
# Out:
# 0    9
# 1    2
# 2    6
# 3    4
# 4    8
# Name: study, dtype: int64

# %%
coefficient,yintercept=np.polyfit(df['study'],df['results'],1)
print(coefficient)
print(yintercept)
# Out:
# 6.036585365853663
# 42.98780487804876

# %%
df['prediction']=np.array([97.3,55.1,79.2,67.1,91.3])
df
# Out:
#    study  results  prediction
# 0      9      100        97.3
# 1      2       50        55.1
# 2      6       80        79.2
# 3      4       75        67.1
# 4      8       85        91.3

# %%
# make a function to multiply prediction=study * coefficient + yintercept


def fsilly(d):
  return d['study'] * coefficient + yintercept



df['prediction']=df.apply(fsilly,axis=1)

df
# Out:
#    study  results  prediction
# 0      9      100   97.317073
# 1      2       50   55.060976
# 2      6       80   79.207317
# 3      4       75   67.134146
# 4      8       85   91.280488

# %%
# now calculate the LSE for each row using the same approach
# Out:
#    study  results
# 0      9      100
# 1      2       50
# 2      6       80
# 3      4       75
# 4      8       85
